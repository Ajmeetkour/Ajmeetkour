# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajmeetkour/Ajmeetkour/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from google.colab import files

# %%
ima = cv2.imread('pr1.jpeg',-1)
from google.colab import drive
drive.mount('/content/drive')
plt.imshow(ima)
# Out:
# Mounted at /content/drive

# %%
ima = cv2.imread('pr1.jpeg',1)
plt.imshow(ima)

# %%
ima = cv2.imread('pr1.jpeg',0)
plt.imshow(ima)

# %%
ima = cv2.imread('pr1.jpeg',1)
imag = cv2.cvtColor(ima,cv2.COLOR_BGR2RGB)
plt.imshow(imag)

# %%
ima = cv2.imread('pr1.jpeg',1)
imag = cv2.cvtColor(ima,cv2.COLOR_BGR2HSV)
plt.imshow(imag)

# %%
ima = cv2.imread('pr1.jpeg',1)
imag = cv2.cvtColor(ima,cv2.COLOR_BGR2GRAY)
plt.imshow(imag)

# %%
from google.colab import drive
drive.mount('/content/drive')
